# %%
import pandas as pd

# %%
final=pd.read_csv('final_dataset.csv')

# %%
links=pd.read_excel('Influencer_with_links.xlsx')
print(links[0:5])
# Out:
#                  name                                               id  \
# 0           philCohen     https://www.instagram.com/thepacman82/?hl=en
# 1      urvashirautela  https://www.instagram.com/urvashirautela/?hl=en
# 2  Danielle Bernstein      https://www.instagram.com/weworewhat/?hl=en
# 3                gaby       https://www.instagram.com/gabalabbb/?hl=en
# 4         zaarayesmin     https://www.instagram.com/zaarayesmin/?hl=en
#
#                                     Profile pic link
# 0  https://instagram.fdel27-1.fna.fbcdn.net/v/t51...
# 1  https://instagram.fdel27-1.fna.fbcdn.net/v/t51...
# 2  https://instagram.fdel27-1.fna.fbcdn.net/v/t51...
# 3  https://instagram.fdel27-1.fna.fbcdn.net/v/t51...
# 4  https://instagram.fdel27-1.fna.fbcdn.net/v/t51...

# %%
print(final[0:5])

# %%
result = pd.merge(final, links, on="name")

# %%
print(result[0:5])
# Out:
#                  name  total_videos  average_videos_views  \
# 0           philCohen             0                   NaN
# 1      urvashirautela           306          1.702444e+06
# 2  Danielle Bernstein             0                   NaN
# 3                gaby             0                   NaN
# 4         zaarayesmin             0                   NaN
#
#    average_videos_comments  total_posts  average_post_comments  \
# 0                      NaN          274             106.237226
# 1              4595.986928          608            4223.912829
# 2                      NaN          248             206.241935
# 3                      NaN          271             113.166052
# 4                      NaN          121             521.628099
#
#    average_post_likes                                        description  \
# 0        10113.905109    thepacman82 [ad]Intotheweekendwithheadtotoe ...
# 1       595724.907895    urvashirautela Verified SohonouredtoplayCleo...
# ...

# %%
indexes = result[result['country'].str.lower() != 'USA'.lower()].index

# %%
result.drop(indexes, inplace=True)

# %%
result=result.sort_values(by="average_post_comments", ascending=False)
print(result)
# Out:
#                    name  total_videos  average_videos_views  \
# 122       kendalljenner             0                   NaN
# 125         kyliejenner             0                   NaN
# 146         selenagomez             0                   NaN
# 59           niallhoran             0                   NaN
# 100        billieeilish             0                   NaN
# 98         arianagrande             0                   NaN
# 129    milliebobbybrown             0                   NaN
# 50               cardib             0                   NaN
# 60           nickiminaj             0                   NaN
# 103          chrisevans             0                   NaN
# 5               zendaya             0                   NaN
# 141      robertdowneyjr             0                   NaN
# 104       chrissyteigen             0                   NaN
# 37           demilovato             0                   NaN
# 118        justinbieber             0                   NaN
# ...

# %%
for d in result.values:
    print(d[0],d[10],d[11],d[12])
# Out:
# kendalljenner fashion/makeup https://www.instagram.com/kendalljenner/ https://instagram.fdel27-1.fna.fbcdn.net/v/t51.2885-19/s320x320/135811429_139036817943437_5718038198453340319_n.jpg?tp=1&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_ohc=9l1RQQ8ez9YAX_Fw39S&oh=24127ecb1217bdfe7e07dab2d321b30c&oe=606DE685
# kyliejenner fashion/makeup https://www.instagram.com/kyliejenner/ https://instagram.fdel27-1.fna.fbcdn.net/v/t51.2885-19/s320x320/123885563_855075811697113_8647373123046258603_n.jpg?tp=1&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_ohc=DxJXf521ui0AX_yUiBr&oh=b4ee375cb2b769bddbe235a893859c62&oe=606DA9AA
# selenagomez singer/makeup https://www.instagram.com/selenagomez/ https://instagram.fdel27-1.fna.fbcdn.net/v/t51.2885-19/s320x320/142428646_741794190097792_7655066869999087337_n.jpg?tp=1&_nc_ht=instagram.fdel27-1.fna.fbcdn.net&_nc_ohc=rDQg1dyPNMoAX-mMNEh&oh=326acd897ea8f3fbddd04c6a0199cb06&oe=606F2691
# ...

# %%
onCountryFilter

# %%
links=pd.read_excel('C:\\Users\\shash\\Desktop\\Data_Science\\Major2020\\webScrapping/Influencer_with_links.xlsx', encoding='unicode_escape')

# %%
print(final['country'].unique())
# Out:
# ['USA' 'india' 'france' 'canada' 'iran' 'usa' 'germany' 'japan' 'china'
#  'spain' 'italy' 'uk' 'korea' 'newzealand' 'inida' 'pakistan' 'brazil']
